# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
from torch.optim import SGD
from torch.nn import CrossEntropyLoss

from time import time
import copy

# %%
seq_len = 10
batch_size = 3
hidden_size = 5
num_layers = 1

# %% [markdown]
# ### Prepare Data

# %%
inputs = Variable(torch.randn(batch_size, seq_len, hidden_size))
labels = Variable(torch.ones(batch_size, seq_len).long())

inputs.size(), labels.size()
print(inputs)
# Out:
# Variable containing:
# (0 ,.,.) =
#  -0.4896 -0.2160 -0.6313 -0.3543  0.2337
#  -0.0718  0.5989  0.8464  1.5978 -0.0819
#  -0.9158  0.5622 -0.7768 -1.1263 -1.0465
#   0.4506 -0.0126 -0.8850  0.0562 -2.5094
#   0.7123  0.3983 -0.7156 -0.0581  1.9640
#  -0.4603 -1.1451  0.4822  1.2087  0.1134
#   0.3681  1.4029  0.4841 -0.3085  0.6774
#   1.8666  0.7289 -0.7285  1.5165 -0.9713
#   0.1606 -0.0850  0.5290  0.8232  0.3798
#   0.1931 -1.1215 -2.9263  2.3361 -0.8520
#
# (1 ,.,.) =
#   1.2109 -0.0862 -0.1067 -0.5303 -0.1768
#   0.5569 -0.1062 -0.5554  0.2678 -1.4154
#   0.7367 -2.3189 -0.0328  0.9362  1.1795
#   1.5108 -1.2707  0.3172 -2.9128  0.0304
#  -0.6279  0.2067 -1.7887 -1.0441 -0.2283
#   0.5645 -0.1671  0.1792 -0.0699  0.9892
#  -0.2849  0.5176  0.7113  1.3107  0.9954
#   0.8644 -1.4601 -0.4753 -0.0710  0.0877
#   0.4778  2.1989  1.9863 -0.3994  0.1753
#   0.1334 -1.6774 -0.4392  1.6171  1.8517
#
# (2 ,.,.) =
#  -1.0962 -0.4176 -0.3727  1.3332  0.1398
#  -0.0092 -0.8003  1.1821  0.6830 -0.2044
#  -0.8851 -1.2152 -0.2499 -1.8230 -0.4599
#  -0.3224  0.6446 -0.3108 -0.3880  1.9203
#   0.6759 -0.5035 -0.8082 -0.5618 -0.5379
#  -0.4874  0.1965  0.6809  0.7698 -0.3369
#  -1.1884  1.3489  0.1651 -0.6744  0.3683
#  -1.6780 -0.3179  1.1899 -0.2550 -1.1585
#  -0.7335  0.5347  0.9432  0.4187  0.6849
#   0.5588  0.0950 -2.5957  0.5032 -0.3663
# [torch.FloatTensor of size 3x10x5]

# %% [markdown]
# ### Define model, Loss function, optimizer

# %%
rnn = nn.RNN( hidden_size, hidden_size, num_layers, batch_first=True)
h_n = Variable(torch.randn(1, batch_size, hidden_size))

loss_fn = CrossEntropyLoss()
opt = SGD(rnn.parameters(), lr=0.01)

# %% [markdown]
# ### RNN module

# %%
start = time()

for i in range(1000):
    loss = 0
    
    out, last_h = rnn(inputs, h_n)
    
    # out: [batch_size, seq_len, hidden_size]
    # lables: [batch_size, seq_len]
    
    for j in range(seq_len):
        loss += loss_fn(out[:,j,:], labels[:,j])
        
    opt.zero_grad()
    loss.backward()
    opt.step()
    
    if (i+1) % 100 == 0:
        print(loss)

print(f'{time() - start:.2f}')
# Out:
# Variable containing:
#  5.1214
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.7259
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.5771
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.4747
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.4322
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.4101
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3961
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3863
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3790
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3733
# [torch.FloatTensor of size 1]
#
# 16.22

# %% [markdown]
# ### RNNCell

# %%
rnncell = nn.RNNCell(hidden_size, hidden_size)
loss_fn = CrossEntropyLoss()
opt = SGD(rnncell.parameters(), lr=0.01)

# %%
inputs = Variable(torch.randn(batch_size,seq_len, hidden_size))
labels = Variable(torch.ones(batch_size, seq_len).long())
h = Variable(torch.randn(batch_size,hidden_size))

# %%
start = time()
for i in range(1000):
    loss = 0
    
    h_next = Variable(h.data.new(batch_size,hidden_size))

    for j in range(seq_len):
        h_next = rnncell(inputs[:,j,:], h_next)
        loss += loss_fn(h_next, labels[:, j])
        
    opt.zero_grad()
    loss.backward()
    opt.step()

    if (i+1) % 5 == 0:
        print(loss)

print(f'{time() - start:.2f}')
# Out:
# Variable containing:
#  4.6914
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3650
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3630
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3580
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3634
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3626
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3627
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3623
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3621
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3620
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.6896
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3617
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3578
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3657
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3612
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3559
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3610
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3611
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3607
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3648
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3568
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3605
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3609
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3617
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3599
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3640
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3596
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3401
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3596
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.6868
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3635
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3541
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.6863
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3588
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3538
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3537
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3396
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3396
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3548
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3582
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3587
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3394
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3579
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3619
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3529
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3541
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3527
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3573
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3390
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3525
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3528
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3608
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3388
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3567
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3606
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.6837
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3518
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3510
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3569
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3568
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3566
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3565
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3558
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3557
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3556
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3511
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3554
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3521
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3554
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3553
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3552
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3498
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.6819
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3517
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3377
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3548
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.6815
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3544
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3376
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3375
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3375
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.6811
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3510
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3540
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.6808
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3538
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3495
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3372
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3549
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3371
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3534
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3503
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3533
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3567
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3494
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3493
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3531
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3563
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3368
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3487
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3528
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.6797
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3530
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.6795
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3523
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3558
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3482
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3521
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3526
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3521
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3524
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3472
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3517
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3488
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3551
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3515
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3487
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3519
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3469
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3475
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3517
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3511
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.6782
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3515
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3472
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3465
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3481
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3509
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3479
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3507
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3505
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3505
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3477
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.6775
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3503
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3502
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3506
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3501
# [torch.FloatTensor of size 1]
# Variable containing:
#  4.3505
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3464
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3499
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3498
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3498
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3497
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.6768
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3454
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3527
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3352
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3468
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3459
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3467
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3493
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.6764
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.6764
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3522
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3456
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3464
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3457
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3488
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3488
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3447
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3497
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3486
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3452
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3517
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3454
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3484
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3450
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3483
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3514
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3482
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3512
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3481
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3482
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3480
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3480
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3447
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3480
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3479
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3477
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3477
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3477
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.6751
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3437
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3343
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3344
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3479
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3478
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3343
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3503
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.6746
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3472
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3481
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3471
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3471
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3342
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3433
# [torch.FloatTensor of size 1]
#
# Variable containing:
#  4.3432
# [torch.FloatTensor of size 1]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-c4cfa292dbc4> in <module>()
#       6
#       7     for j in range(seq_len):
# ----> 8         h_next = rnncell(inputs[:,j,:], h_next)
#       9         loss += loss_fn(h_next, labels[:, j])
#      10
#
# ~\AppData\Local\conda\conda\envs\tf\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     204
#     205     def __call__(self, *input, **kwargs):
# --> 206         result = self.forward(*input, **kwargs)
#     207         for hook in self._forward_hooks.values():
#     208             hook_result = hook(self, input, result)
#
# ~\AppData\Local\conda\conda\envs\tf\lib\site-packages\torch\nn\modules\rnn.py in forward(self, input, hx)
#     423             input, hx,
#     424             self.weight_ih, self.weight_hh,
# --> 425             self.bias_ih, self.bias_hh,
#     426         )
#     427
#
# ~\AppData\Local\conda\conda\envs\tf\lib\site-packages\torch\nn\_functions\rnn.py in RNNTanhCell(input, hidden, w_ih, w_hh, b_ih, b_hh)
#      16
#      17 def RNNTanhCell(input, hidden, w_ih, w_hh, b_ih=None, b_hh=None):
# ---> 18     hy = F.tanh(F.linear(input, w_ih, b_ih) + F.linear(hidden, w_hh, b_hh))
#      19     return hy
#      20
#
# ~\AppData\Local\conda\conda\envs\tf\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#     451         return _functions.linear.Linear.apply(input, weight)
#     452     else:
# --> 453         return _functions.linear.Linear.apply(input, weight, bias)
#     454
#     455
#
# ~\AppData\Local\conda\conda\envs\tf\lib\site-packages\torch\nn\_functions\linear.py in forward(ctx, input, weight, bias)
#      10         ctx.save_for_backward(input, weight, bias)
#      11         output = input.new(input.size(0), weight.size(0))
# ---> 12         output.addmm_(0, 1, input, weight.t())
#      13         if bias is not None:
#      14             # cuBLAS doesn't support 0 strides in sger, so we can't use expand
#
# KeyboardInterrupt:
